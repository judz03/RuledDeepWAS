# %% [markdown]
# # GWAS Catalog data exploration
#
# He we analyze the data contained in the last version of the GWAS Catalog data.

# %%
import pandas as pd
import numpy as np
import os

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# /home/moisessotelo/Documents/Universidad de Guadalajara/MBCI/Projecto/RuledDeepWAS/Scripts Preprocessing

# %%
# Import the last version of the GWAS Catalog
gwas_catalog_path = "/mnt/sda1/Databases/GWAS_Catalog_DATA/gwas_catalog_v1.0.2-associations_e110_r2023-09-25.tsv"
gwas_catalog = pd.read_csv(gwas_catalog_path, delimiter = "\t")
gwas_catalog.head()
# Out:
# /tmp/ipykernel_12826/3863073644.py:3: DtypeWarning: Columns (9,11,12,13,23,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   gwas_catalog = pd.read_csv(gwas_catalog_path, delimiter = "\t")
#   DATE ADDED TO CATALOG  PUBMEDID     FIRST AUTHOR        DATE    JOURNAL  \
# 0            2008-07-01  18391951  Gudbjartsson DF  2008-04-06  Nat Genet
# 1            2008-07-01  18391951  Gudbjartsson DF  2008-04-06  Nat Genet
# 2            2008-07-01  18391951  Gudbjartsson DF  2008-04-06  Nat Genet
# 3            2008-07-01  18391951  Gudbjartsson DF  2008-04-06  Nat Genet
# 4            2008-07-01  18391951  Gudbjartsson DF  2008-04-06  Nat Genet
#
#                                    LINK  \
# 0  www.ncbi.nlm.nih.gov/pubmed/18391951
# 1  www.ncbi.nlm.nih.gov/pubmed/18391951
# 2  www.ncbi.nlm.nih.gov/pubmed/18391951
# 3  www.ncbi.nlm.nih.gov/pubmed/18391951
# 4  www.ncbi.nlm.nih.gov/pubmed/18391951
#
# ...

# %%
gwas_catalog.shape
# Out:
# (552954, 38)

# %%
gwas_catalog.columns
# Out:
# Index(['DATE ADDED TO CATALOG', 'PUBMEDID', 'FIRST AUTHOR', 'DATE', 'JOURNAL',
#        'LINK', 'STUDY', 'DISEASE/TRAIT', 'INITIAL SAMPLE SIZE',
#        'REPLICATION SAMPLE SIZE', 'REGION', 'CHR_ID', 'CHR_POS',
#        'REPORTED GENE(S)', 'MAPPED_GENE', 'UPSTREAM_GENE_ID',
#        'DOWNSTREAM_GENE_ID', 'SNP_GENE_IDS', 'UPSTREAM_GENE_DISTANCE',
#        'DOWNSTREAM_GENE_DISTANCE', 'STRONGEST SNP-RISK ALLELE', 'SNPS',
#        'MERGED', 'SNP_ID_CURRENT', 'CONTEXT', 'INTERGENIC',
#        'RISK ALLELE FREQUENCY', 'P-VALUE', 'PVALUE_MLOG', 'P-VALUE (TEXT)',
#        'OR or BETA', '95% CI (TEXT)', 'PLATFORM [SNPS PASSING QC]', 'CNV',
#        'MAPPED_TRAIT', 'MAPPED_TRAIT_URI', 'STUDY ACCESSION',
#        'GENOTYPING TECHNOLOGY'],
#       dtype='object')

# %%
desired_columns = ["DISEASE/TRAIT","REGION", "CHR_ID", "CHR_POS", "REPORTED GENE(S)",
                   "UPSTREAM_GENE_DISTANCE", "DOWNSTREAM_GENE_DISTANCE", "SNPS", "STRONGEST SNP-RISK ALLELE",
                   "CNV", "STUDY ACCESSION", "INTERGENIC"]

# %%
gwas_catalog[desired_columns]
# Out:
#                         DISEASE/TRAIT   REGION CHR_ID     CHR_POS  \
# 0                              Height     3q23      3   141383991
# 1                              Height   Xq21.1      X    79393696
# 2                              Height    17q22     17    56772968
# 3                              Height   6q23.1      6   130037283
# 4                              Height   2q37.1      2   231931900
# ...                               ...      ...    ...         ...
# 552949  Retinal arteriolar tortuosity  11p15.4     11   8869377.0
# 552950  Retinal arteriolar tortuosity  14q23.1     14  60606157.0
# 552951  Retinal arteriolar tortuosity  1p36.32      1   3347626.0
# 552952  Retinal arteriolar tortuosity  10q21.3     10  63541965.0
# 552953  Retinal arteriolar tortuosity      NaN    NaN         NaN
#
#                          REPORTED GENE(S)  UPSTREAM_GENE_DISTANCE  \
# 0                                  ZBTB38                     NaN
# ...

# %%
gwas_catalog["DISEASE/TRAIT"].value_counts()
# Out:
# DISEASE/TRAIT
# Height                                                                                                                                                        23784
# Body mass index                                                                                                                                                9440
# Electrocardiogram morphology (amplitude at temporal datapoints)                                                                                                5501
# Educational attainment                                                                                                                                         5254
# Type 2 diabetes                                                                                                                                                4665
# ...
